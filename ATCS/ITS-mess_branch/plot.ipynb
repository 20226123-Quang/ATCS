# %% [markdown]
# # So sánh các thông số giao thông từ 2 file JSON
#
# Notebook này sẽ:
#
# - Đọc 2 file: "traffic_metrics.json" và "traffic_metrics copy.json" (cùng thư mục với notebook).
# - Hiển thị bảng tổng hợp các thông số.
# - Vẽ biểu đồ so sánh theo 2 nhóm: thời gian (giây) và số lượng/độ dài.
#
# Lưu ý: Nếu thiếu thư viện vẽ, bạn có thể cài `matplotlib` bằng:
#
# ```
# %pip install matplotlib
# ```

# %%
# Đọc 2 file JSON và chuẩn hóa dữ liệu
import json, os
from typing import Dict, List, Any

files = ["TUC4.json", "fixtime4.json", "PPO1.json", "PPO_multi.json"]
metric_keys: List[str] = [
    "average_wait_time",
    "total_vehicles_waited",
    "average_queue_length",
    "max_queue_length",
    "queue_measurements",
    "average_travel_time",
    "min_travel_time",
    "max_travel_time",
    "total_vehicles_traveled",
]

data: Dict[str, Dict[str, Any]] = {}
missing = []
for f in files:
    if not os.path.exists(f):
        missing.append(f)
        continue
    with open(f, "r", encoding="utf-8") as fh:
        payload = json.load(fh)
    label = os.path.splitext(os.path.basename(f))[0]
    if isinstance(payload, dict):
        row = {k: payload.get(k, None) for k in metric_keys}
    else:
        raise ValueError(f"Nội dung {f} không đúng định dạng JSON object.")
    data[label] = row

if missing:
    print("Thiếu file:", ", ".join(missing))
if len(data) < 2:
    print("Cảnh báo:", len(data), "file hợp lệ. Tiếp tục với những gì có.")

# Xem nhanh dữ liệu đã nạp
data
# Out:
# {'TUC4': {'average_wait_time': 46.402061855670105,
#   'total_vehicles_waited': 194,
#   'average_queue_length': 11.4375,
#   'max_queue_length': 20.0,
#   'queue_measurements': 32,
#   'average_travel_time': 58.82954545454545,
#   'min_travel_time': 9.0,
#   'max_travel_time': 171.0,
#   'total_vehicles_traveled': 264},
#  'fixtime4': {'average_wait_time': 46.380710659898476,
#   'total_vehicles_waited': 197,
#   'average_queue_length': 11.6875,
#   'max_queue_length': 21.0,
#   'queue_measurements': 32,
#   'average_travel_time': 59.515151515151516,
#   'min_travel_time': 9.0,
#   'max_travel_time': 231.0,
#   'total_vehicles_traveled': 264},
#  'PPO1': {'average_wait_time': 36.514150943396224,
#   'total_vehicles_waited': 212,
#   'average_queue_length': 6.8,
#   'max_queue_length': 22.0,
#   'queue_measurements': 55,
#   'average_travel_time': 55.35227272727273,
#   'min_travel_time': 10.0,
#   'max_travel_time': 171.0,
#   'total_vehicles_traveled': 264},
#  'PPO_multi': {'average_wait_time': 21.159420289855074,
#   'total_vehicles_waited': 207,
#   'average_queue_length': 4.506329113924051,
#   'max_queue_length': 14.0,
#   'queue_measurements': 79,
#   'average_travel_time': 42.234848484848484,
#   'min_travel_time': 10.0,
#   'max_travel_time': 116.0,
#   'total_vehicles_traveled': 264}}

# %%
# Hiển thị bảng tổng hợp (pandas nếu có, fallback nếu không)
try:
    import pandas as pd
    from IPython.display import display
    df = pd.DataFrame.from_dict(data, orient='index')
    display(df)
except Exception as e:
    print("Không thể dùng pandas; hiển thị dạng dict (", e, "):")
    import pprint
    pprint.pprint(data)
# Out:
#            average_wait_time  total_vehicles_waited  average_queue_length  \
# TUC4               46.402062                    194             11.437500
# fixtime4           46.380711                    197             11.687500
# PPO1               36.514151                    212              6.800000
# PPO_multi          21.159420                    207              4.506329
#
#            max_queue_length  queue_measurements  average_travel_time  \
# TUC4                   20.0                  32            58.829545
# fixtime4               21.0                  32            59.515152
# PPO1                   22.0                  55            55.352273
# PPO_multi              14.0                  79            42.234848
#
#            min_travel_time  max_travel_time  total_vehicles_traveled
# TUC4                   9.0            171.0                      264
# fixtime4               9.0            231.0                      264
# PPO1                  10.0            171.0                      264
# PPO_multi             10.0            116.0                      264

# %%
# Vẽ biểu đồ so sánh 3 chỉ số chính: average_wait_time, average_travel_time, average_queue_length
import numpy as np

try:
    import matplotlib.pyplot as plt
except Exception as e:
    raise ImportError("Cần cài matplotlib: dùng %pip install matplotlib") from e

main_metrics = [
    "average_wait_time",
    "average_travel_time",
    "average_queue_length",
]

labels = list(data.keys())

def collect(vals_keys):
    arr = []
    for lb in labels:
        row = data[lb]
        arr.append([row.get(k, np.nan) for k in vals_keys])
    return np.array(arr)

main_vals = collect(main_metrics)

fig, ax = plt.subplots(figsize=(8, 6))

x = np.arange(len(main_metrics))
width = 0.8 / max(1, len(labels))
for idx, lb in enumerate(labels):
    ax.bar(x + (idx - (len(labels)-1)/2)*width, main_vals[idx], width=width, label=lb)
ax.set_xticks(x)
ax.set_xticklabels([m.replace('_','\n') for m in main_metrics])
ax.set_title("So sánh các chỉ số chính")
ax.set_ylabel("Giá trị")
ax.legend()

plt.tight_layout()
plt.show()
